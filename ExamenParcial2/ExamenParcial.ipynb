# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df = pd.read_csv('train.csv')
# Out:
# C:\Users\M-80-1\AppData\Local\Temp\ipykernel_9108\2436019669.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('train.csv')

# %%
df
# Out:
#             ID Customer_ID     Month           Name   Age          SSN  \
# 0       0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265
# 1       0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265
# 2       0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265
# 3       0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265
# 4       0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265
# ...        ...         ...       ...            ...   ...          ...
# 99995  0x25fe9  CUS_0x942c     April          Nicks    25  078-73-5990
# 99996  0x25fea  CUS_0x942c       May          Nicks    25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June          Nicks    25  078-73-5990
# 99998  0x25fec  CUS_0x942c      July          Nicks    25  078-73-5990
# 99999  0x25fed  CUS_0x942c    August          Nicks    25  078-73-5990
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# ...

# %%
df.dtypes
# Out:
# ID                           object
# Customer_ID                  object
# Month                        object
# Name                         object
# Age                          object
# SSN                          object
# Occupation                   object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                  object
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Changed_Credit_Limit         object
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# ...

# %%
dflimpia = df.drop(['ID','Customer_ID','Name','Payment_Behaviour','SSN','Type_of_Loan','Month','Credit_History_Age','Age','Monthly_Balance'], axis=1)

# %%
dflimpia.head()
# Out:
#   Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0  Scientist      19114.12            1824.843333                  3
# 1  Scientist      19114.12                    NaN                  3
# 2  Scientist      19114.12                    NaN                  3
# 3  Scientist      19114.12                    NaN                  3
# 4  Scientist      19114.12            1824.843333                  3
#
#    Num_Credit_Card  Interest_Rate Num_of_Loan  Delay_from_due_date  \
# 0                4              3           4                    3
# 1                4              3           4                   -1
# 2                4              3           4                    3
# 3                4              3           4                    5
# 4                4              3           4                    6
#
#   Num_of_Delayed_Payment Changed_Credit_Limit  Num_Credit_Inquiries  \
# 0                      7                11.27                   4.0
# ...

# %%
dflimpia.Occupation.unique()
# Out:
# array(['Scientist', '_______', 'Teacher', 'Engineer', 'Entrepreneur',
#        'Developer', 'Lawyer', 'Media_Manager', 'Doctor', 'Journalist',
#        'Manager', 'Accountant', 'Musician', 'Mechanic', 'Writer',
#        'Architect'], dtype=object)

# %%
dflimpia.Occupation = dflimpia.Occupation.map({'Scientist': 1, '_______': 2, 'Teacher': 3, 'Engineer' : 4, 'Entrepreneur' : 5,
       'Developer' : 6, 'Lawyer' : 7, 'Media_Manager' : 8, 'Doctor' : 9, 'Journalist' : 10,
       'Manager' : 11, 'Accountant' : 12, 'Musician' : 13, 'Mechanic' : 14, 'Writer' : 15,
       'Architect' : 16})

# %%
dflimpia.Credit_Mix.unique()
# Out:
# array(['_', 'Good', 'Standard', 'Bad'], dtype=object)

# %%
dflimpia.Credit_Mix = dflimpia.Credit_Mix.map({'_': 1, 'Good': 2, 'Standard' : 3, 'Bad' : 4})

# %%
dflimpia.Credit_Score.unique()
# Out:
# array(['Good', 'Standard', 'Poor'], dtype=object)

# %%
dflimpia.Credit_Score = dflimpia.Credit_Score.map({'Good': 1, 'Standard': 2, 'Poor': 3})

# %%
dflimpia.Payment_of_Min_Amount.unique()
# Out:
# array(['No', 'NM', 'Yes'], dtype=object)

# %%
dflimpia.Payment_of_Min_Amount = dflimpia.Payment_of_Min_Amount.map({'No': 1, 'NM': 2, 'Yes': 3})

# %%
dflimpia
# Out:
#        Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0               1      19114.12            1824.843333                  3
# 1               1      19114.12                    NaN                  3
# 2               1      19114.12                    NaN                  3
# 3               1      19114.12                    NaN                  3
# 4               1      19114.12            1824.843333                  3
# ...           ...           ...                    ...                ...
# 99995          14      39628.99            3359.415833                  4
# 99996          14      39628.99            3359.415833                  4
# 99997          14      39628.99            3359.415833                  4
# 99998          14      39628.99            3359.415833                  4
# 99999          14     39628.99_            3359.415833                  4
#
#        Num_Credit_Card  Interest_Rate Num_of_Loan  Delay_from_due_date  \
# ...

# %%
dflimpia.dtypes
# Out:
# Occupation                    int64
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                  object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Changed_Credit_Limit         object
# Num_Credit_Inquiries        float64
# Credit_Mix                    int64
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Payment_of_Min_Amount         int64
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Credit_Score                  int64
# dtype: object

# %%
dflimpia.Annual_Income = dflimpia.Annual_Income.str.replace(r'[^0-9.]','',regex=True,flags=re.IGNORECASE)

# %%
dflimpia.Annual_Income = pd.to_numeric(dflimpia.Annual_Income)

# %%
dflimpia.Annual_Income.head()
# Out:
# 0    19114.12
# 1    19114.12
# 2    19114.12
# 3    19114.12
# 4    19114.12
# Name: Annual_Income, dtype: float64

# %%
dflimpia.Num_of_Loan= dflimpia.Num_of_Loan.str.replace(r'[^0-9.]','',regex=True,flags=re.IGNORECASE)

# %%
dflimpia.Num_of_Loan = pd.to_numeric(dflimpia.Num_of_Loan)

# %%
dflimpia.Num_of_Loan.head()
# Out:
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4
# Name: Num_of_Loan, dtype: int64

# %%
dflimpia.Num_of_Delayed_Payment = dflimpia.Num_of_Delayed_Payment.str.replace(r'[^0-9.]','',regex=True,flags=re.IGNORECASE)

# %%
dflimpia.Num_of_Delayed_Payment = pd.to_numeric(dflimpia.Num_of_Delayed_Payment)

# %%
dflimpia.Num_of_Delayed_Payment.head()
# Out:
# 0    7.0
# 1    NaN
# 2    7.0
# 3    4.0
# 4    NaN
# Name: Num_of_Delayed_Payment, dtype: float64

# %%
dflimpia.Changed_Credit_Limit = dflimpia.Changed_Credit_Limit.str.replace(r'[^0-9.]','',regex=True,flags=re.IGNORECASE)

# %%
dflimpia.Changed_Credit_Limit = pd.to_numeric(dflimpia.Changed_Credit_Limit)

# %%
dflimpia.Changed_Credit_Limit.head()
# Out:
# 0    11.27
# 1    11.27
# 2      NaN
# 3     6.27
# 4    11.27
# Name: Changed_Credit_Limit, dtype: float64

# %%
dflimpia.Outstanding_Debt = dflimpia.Outstanding_Debt.str.replace(r'[^0-9.]','',regex=True,flags=re.IGNORECASE)

# %%
dflimpia.Outstanding_Debt = pd.to_numeric(dflimpia.Outstanding_Debt)

# %%
dflimpia.Outstanding_Debt.head()
# Out:
# 0    809.98
# 1    809.98
# 2    809.98
# 3    809.98
# 4    809.98
# Name: Outstanding_Debt, dtype: float64

# %%
dflimpia.Amount_invested_monthly = dflimpia.Amount_invested_monthly.str.replace(r'[^0-9.]','',regex=True,flags=re.IGNORECASE)

# %%
dflimpia.Amount_invested_monthly = pd.to_numeric(dflimpia.Amount_invested_monthly)

# %%
dflimpia.Amount_invested_monthly.head()
# Out:
# 0     80.415295
# 1    118.280222
# 2     81.699521
# 3    199.458074
# 4     41.420153
# Name: Amount_invested_monthly, dtype: float64

# %%
dflimpia.dtypes
# Out:
# Occupation                    int64
# Annual_Income               float64
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                   int64
# Delay_from_due_date           int64
# Num_of_Delayed_Payment      float64
# Changed_Credit_Limit        float64
# Num_Credit_Inquiries        float64
# Credit_Mix                    int64
# Outstanding_Debt            float64
# Credit_Utilization_Ratio    float64
# Payment_of_Min_Amount         int64
# Total_EMI_per_month         float64
# Amount_invested_monthly     float64
# Credit_Score                  int64
# dtype: object

# %%
dflimpia.describe()
# Out:
#           Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  100000.000000   1.000000e+05           84998.000000      100000.000000
# mean        8.400890   1.764157e+05            4194.170850          17.091280
# std         4.631139   1.429618e+06            3183.686167         117.404834
# min         1.000000   7.005930e+03             303.645417          -1.000000
# 25%         4.000000   1.945750e+04            1625.568229           3.000000
# 50%         8.000000   3.757861e+04            3093.745000           6.000000
# 75%        12.000000   7.279092e+04            5957.448333           7.000000
# max        16.000000   2.419806e+07           15204.633333        1798.000000
#
#        Num_Credit_Card  Interest_Rate    Num_of_Loan  Delay_from_due_date  \
# count     100000.00000  100000.000000  100000.000000        100000.000000
# mean          22.47443      72.466040      10.761960            21.068780
# ...

# %%
dflimpia.Monthly_Inhand_Salary = dflimpia.Monthly_Inhand_Salary.fillna(dflimpia.Monthly_Inhand_Salary.mean())

# %%
dflimpia.Num_of_Delayed_Payment = dflimpia.Num_of_Delayed_Payment.fillna(dflimpia.Num_of_Delayed_Payment.mean())

# %%
dflimpia.Changed_Credit_Limit = dflimpia.Changed_Credit_Limit.fillna(dflimpia.Changed_Credit_Limit.mean())

# %%
dflimpia.Num_Credit_Inquiries = dflimpia.Num_Credit_Inquiries.fillna(dflimpia.Num_Credit_Inquiries.mean())

# %%
dflimpia.Amount_invested_monthly = dflimpia.Amount_invested_monthly.fillna(dflimpia.Amount_invested_monthly.mean())

# %%
dflimpia.describe()
# Out:
#           Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  100000.000000   1.000000e+05          100000.000000      100000.000000
# mean        8.400890   1.764157e+05            4194.170850          17.091280
# std         4.631139   1.429618e+06            2935.176493         117.404834
# min         1.000000   7.005930e+03             303.645417          -1.000000
# 25%         4.000000   1.945750e+04            1792.084167           3.000000
# 50%         8.000000   3.757861e+04            3852.736667           6.000000
# 75%        12.000000   7.279092e+04            5371.525000           7.000000
# max        16.000000   2.419806e+07           15204.633333        1798.000000
#
#        Num_Credit_Card  Interest_Rate    Num_of_Loan  Delay_from_due_date  \
# count     100000.00000  100000.000000  100000.000000        100000.000000
# mean          22.47443      72.466040      10.761960            21.068780
# ...

# %%
corr = dflimpia.corr()
corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_cb725_row0_col0, #T_cb725_row1_col1, #T_cb725_row2_col2, #T_cb725_row3_col3, #T_cb725_row4_col4, #T_cb725_row5_col5, #T_cb725_row6_col6, #T_cb725_row7_col7, #T_cb725_row8_col8, #T_cb725_row9_col9, #T_cb725_row10_col10, #T_cb725_row11_col11, #T_cb725_row12_col12, #T_cb725_row13_col13, #T_cb725_row14_col14, #T_cb725_row15_col15, #T_cb725_row16_col16, #T_cb725_row17_col17 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# ...

# %%
data_x = dflimpia.drop(['Occupation', 'Annual_Income','Num_Bank_Accounts','Num_Credit_Card','Interest_Rate','Num_of_Loan','Num_of_Delayed_Payment',
                       'Total_EMI_per_month','Amount_invested_monthly','Credit_Score'],axis=1)
data_y = dflimpia.Credit_Score

# %%
data_x.head()
# Out:
#    Monthly_Inhand_Salary  Delay_from_due_date  Changed_Credit_Limit  \
# 0            1824.843333                    3             11.270000
# 1            4194.170850                   -1             11.270000
# 2            4194.170850                    3             10.465678
# 3            4194.170850                    5              6.270000
# 4            1824.843333                    6             11.270000
#
#    Num_Credit_Inquiries  Credit_Mix  Outstanding_Debt  \
# 0                   4.0           1            809.98
# 1                   4.0           2            809.98
# 2                   4.0           2            809.98
# 3                   4.0           2            809.98
# 4                   4.0           2            809.98
#
#    Credit_Utilization_Ratio  Payment_of_Min_Amount
# 0                 26.822620                      1
# 1                 31.944960                      1
# 2                 28.609352                      1
# ...

# %%
data_y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Credit_Score, dtype: int64

# %%
train_x, test_x,train_y,test_y = train_test_split(data_x,data_y,test_size=0.1)

# %%
kneigh = KNeighborsClassifier(n_neighbors=4)

# %%
kneigh.fit(train_x,train_y)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
y_pred_kn = kneigh.predict(test_x)

# %%
print(f'El Score de entrenamiento de KNN es:  {round(kneigh.score(test_x,test_y),4)*100}')
# Out:
# El Score de entrenamiento de KNN es:  75.13

# %%
tree = DecisionTreeClassifier()

# %%
tree.fit(train_x,train_y)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_tree = tree.predict(test_x)

# %%
print(f'El Score de entrenamiento de KNN es:  {round(tree.score(test_x,test_y),4)*100}')
# Out:
# El Score de entrenamiento de KNN es:  67.33
